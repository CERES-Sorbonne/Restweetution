# %%
import requests
import json
import os
import time
import hashlib

from functools import wraps
from pathlib import Path
from enum import Enum

# %%
def generate_token():
    with open(r"C:\Users\Orion\Documents\Projets\CERES\credentials_pro.json", 'r') as f:
        return f"Bearer {json.load(f)['token']}"

# %%
API_ROUTE = "https://api.twitter.com/2/"
STREAM_ROUTE = "tweets/search/stream"
RULES_ROUTE = "tweets/search/stream/rules"
FULL_SEARCH_ROUTE = "tweets/search/all"
ROOT_FOLDER = r"C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets"
# maximum size of the collect in octets
MAX_SIZE = 10000000
TOKEN = generate_token()
params = {
    "tweet.fields": "public_metrics,referenced_tweets",
    "expansions": "author_id,in_reply_to_user_id,attachments.media_keys",
    "media.fields": "url",
    "user.fields": "id,verified"
}

# %%
s = requests.Session()
s.headers.update({"Authorization": TOKEN})

# %%
def get_full_user_tweets(user_id, resume_token=None):
    params_search = {
    "tweet.fields": "public_metrics,referenced_tweets,possibly_sensitive,created_at,source,reply_settings,withheld",
    "expansions": "author_id,in_reply_to_user_id,attachments.media_keys",
    "media.fields": "url,public_metrics,type,alt_text",
    "user.fields": "id,verified",
    "max_results": 500,
    "start_time": "2006-12-01T00:00:00Z",
    "end_time": "2021-09-26T00:00:00Z"
    }
    author_id = user_id
    query = 'from:'+ str(author_id)
    new_token = "" if not resume_token else resume_token
    i = 0
    total = 0
    while new_token is not None:
        if new_token != "":
            params_search['next_token'] = new_token
        res = s.get(API_ROUTE + FULL_SEARCH_ROUTE + '?query=' + query, params=params_search)
        data = res.json()
        count = data.get('meta', {}).get('result_count', 0)
        total += count
        print(f'on a récupéré {total} résultats')
        if  count == 0:
            print(f'aucun résultat pour cette requête, l"id est peut etre invalide: {user_id}')
            new_token = None
        with open(os.path.join(ROOT_FOLDER, str(author_id) + '-' + str(i) + '.json'), 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=4)
        new_token = data['meta'].get('next_token', None)
        if i % 10 == 0:
            print("5000 results collected, making a break")
            time.sleep(30)
        i += 1
    print('FINI')

# %%
get_full_user_tweets(19822406, resume_token="1jzu9lk96gu5npw3ja2621m04xz6xebmxpumgedy3o1p")
# Out:
# on a récupéré 498 résultats
# 5000 results collected, making a break
# on a récupéré 995 résultats
# on a récupéré 1493 résultats
# on a récupéré 1989 résultats
# on a récupéré 2485 résultats
# on a récupéré 2980 résultats
# on a récupéré 3471 résultats
# on a récupéré 3970 résultats
# on a récupéré 4467 résultats
# on a récupéré 4945 résultats
# on a récupéré 5443 résultats
# 5000 results collected, making a break
# on a récupéré 5941 résultats
# on a récupéré 6439 résultats
# on a récupéré 6938 résultats
# on a récupéré 7434 résultats
# on a récupéré 7929 résultats
# on a récupéré 8427 résultats
# on a récupéré 8922 résultats
# on a récupéré 9421 résultats
# on a récupéré 9918 résultats
# on a récupéré 10413 résultats
# 5000 results collected, making a break
# on a récupéré 10906 résultats
# on a récupéré 11400 résultats
# on a récupéré 11897 résultats
# on a récupéré 12394 résultats
# on a récupéré 12867 résultats
# on a récupéré 13365 résultats
# on a récupéré 13864 résultats
# on a récupéré 14360 résultats
# on a récupéré 14852 résultats
# on a récupéré 15351 résultats
# 5000 results collected, making a break
# on a récupéré 15833 résultats
# on a récupéré 16331 résultats
# on a récupéré 16827 résultats
# on a récupéré 17321 résultats
# on a récupéré 17820 résultats
# on a récupéré 18316 résultats
# on a récupéré 18812 résultats
# on a récupéré 19308 résultats
# on a récupéré 19796 résultats
# on a récupéré 20295 résultats
# 5000 results collected, making a break
# on a récupéré 20788 résultats
# on a récupéré 21285 résultats
# on a récupéré 21782 résultats
# on a récupéré 22281 résultats
# on a récupéré 22774 résultats
# on a récupéré 23271 résultats
# on a récupéré 23766 résultats
# on a récupéré 24256 résultats
# on a récupéré 24748 résultats
# on a récupéré 25242 résultats
# 5000 results collected, making a break
# on a récupéré 25718 résultats
# on a récupéré 26213 résultats
# on a récupéré 26712 résultats
# on a récupéré 27211 résultats
# on a récupéré 27707 résultats
# on a récupéré 28204 résultats
# on a récupéré 28700 résultats
# on a récupéré 29197 résultats
# on a récupéré 29694 résultats
# on a récupéré 30191 résultats
# 5000 results collected, making a break
# on a récupéré 30679 résultats
# on a récupéré 31177 résultats
# on a récupéré 31669 résultats
# on a récupéré 32165 résultats
# on a récupéré 32660 résultats
# on a récupéré 33154 résultats
# on a récupéré 33653 résultats
# on a récupéré 34143 résultats
# on a récupéré 34637 résultats
# on a récupéré 35136 résultats
# 5000 results collected, making a break
# on a récupéré 35628 résultats
# on a récupéré 36123 résultats
# on a récupéré 36619 résultats
# on a récupéré 37113 résultats
# on a récupéré 37611 résultats
# on a récupéré 38107 résultats
# on a récupéré 38595 résultats
# on a récupéré 39094 résultats
# on a récupéré 39594 résultats
# on a récupéré 40093 résultats
# 5000 results collected, making a break
# on a récupéré 40591 résultats
# on a récupéré 41088 résultats
# on a récupéré 41586 résultats
# on a récupéré 42078 résultats
# on a récupéré 42575 résultats
# on a récupéré 43068 résultats
# on a récupéré 43560 résultats
# on a récupéré 44059 résultats
# on a récupéré 44555 résultats
# on a récupéré 45053 résultats
# 5000 results collected, making a break
# on a récupéré 45546 résultats
# on a récupéré 46043 résultats
# on a récupéré 46534 résultats
# on a récupéré 47019 résultats
# on a récupéré 47511 résultats
# on a récupéré 48004 résultats
# on a récupéré 48496 résultats
# on a récupéré 48989 résultats
# on a récupéré 49484 résultats
# on a récupéré 49977 résultats
# 5000 results collected, making a break
# on a récupéré 50474 résultats
# on a récupéré 50972 résultats
# on a récupéré 51468 résultats
# on a récupéré 51961 résultats
# on a récupéré 52456 résultats
# on a récupéré 52954 résultats
# on a récupéré 53449 résultats
# on a récupéré 53945 résultats
# on a récupéré 54439 résultats
# on a récupéré 54932 résultats
# 5000 results collected, making a break
# on a récupéré 55424 résultats
# on a récupéré 55915 résultats
# on a récupéré 56408 résultats
# on a récupéré 56905 résultats
# on a récupéré 57400 résultats
# on a récupéré 57895 résultats
# on a récupéré 58389 résultats
# on a récupéré 58879 résultats
# on a récupéré 59370 résultats
# on a récupéré 59863 résultats
# 5000 results collected, making a break
# on a récupéré 60350 résultats
# on a récupéré 60844 résultats
# on a récupéré 61337 résultats
# on a récupéré 61836 résultats
# on a récupéré 62335 résultats
# on a récupéré 62834 résultats
# on a récupéré 63327 résultats
# on a récupéré 63812 résultats
# on a récupéré 64310 résultats
# on a récupéré 64808 résultats
# 5000 results collected, making a break
# on a récupéré 65304 résultats
# on a récupéré 65801 résultats
# on a récupéré 66297 résultats
# on a récupéré 66788 résultats
# on a récupéré 67284 résultats
# on a récupéré 67782 résultats
# on a récupéré 68273 résultats
# on a récupéré 68763 résultats
# on a récupéré 69256 résultats
# on a récupéré 69754 résultats
# 5000 results collected, making a break
# on a récupéré 70248 résultats
# on a récupéré 70746 résultats
# on a récupéré 71233 résultats
# on a récupéré 71725 résultats
# on a récupéré 72214 résultats
# on a récupéré 72709 résultats
# on a récupéré 73205 résultats
# on a récupéré 73690 résultats
# on a récupéré 74187 résultats
# on a récupéré 74686 résultats
# 5000 results collected, making a break
# on a récupéré 75186 résultats
# on a récupéré 75684 résultats
# on a récupéré 76170 résultats
# on a récupéré 76666 résultats
# on a récupéré 77162 résultats
# on a récupéré 77654 résultats
# on a récupéré 78150 résultats
# on a récupéré 78636 résultats
# on a récupéré 79132 résultats
# on a récupéré 79629 résultats
# 5000 results collected, making a break
# on a récupéré 80118 résultats
# on a récupéré 80612 résultats
# on a récupéré 81106 résultats
# on a récupéré 81602 résultats
# on a récupéré 82094 résultats
# on a récupéré 82588 résultats
# on a récupéré 83085 résultats
# on a récupéré 83581 résultats
# on a récupéré 84080 résultats
# on a récupéré 84572 résultats
# 5000 results collected, making a break
# on a récupéré 85058 résultats
# on a récupéré 85539 résultats
# on a récupéré 86033 résultats
# on a récupéré 86528 résultats
# on a récupéré 87017 résultats
# on a récupéré 87490 résultats
# on a récupéré 87980 résultats
# on a récupéré 88455 résultats
# on a récupéré 88950 résultats
# on a récupéré 89439 résultats
# 5000 results collected, making a break
# on a récupéré 89937 résultats
# on a récupéré 90435 résultats
# on a récupéré 90929 résultats
# on a récupéré 91425 résultats
# on a récupéré 91920 résultats
# on a récupéré 92414 résultats
# on a récupéré 92907 résultats
# on a récupéré 93399 résultats
# on a récupéré 93895 résultats
# on a récupéré 94394 résultats
# 5000 results collected, making a break
# on a récupéré 94887 résultats
# on a récupéré 95372 résultats
# on a récupéré 95868 résultats
# on a récupéré 96365 résultats
# on a récupéré 96860 résultats
# on a récupéré 97355 résultats
# on a récupéré 97855 résultats
# on a récupéré 98351 résultats
# on a récupéré 98845 résultats
# on a récupéré 99333 résultats
# 5000 results collected, making a break
# on a récupéré 99828 résultats
# on a récupéré 100310 résultats
# on a récupéré 100807 résultats
# on a récupéré 101305 résultats
# on a récupéré 101799 résultats
# on a récupéré 102295 résultats
# on a récupéré 102792 résultats
# on a récupéré 103286 résultats
# on a récupéré 103780 résultats
# on a récupéré 104274 résultats
# 5000 results collected, making a break
# on a récupéré 104767 résultats
# on a récupéré 105266 résultats
# on a récupéré 105752 résultats
# on a récupéré 106245 résultats
# on a récupéré 106742 résultats
# on a récupéré 107237 résultats
# on a récupéré 107737 résultats
# on a récupéré 108230 résultats
# on a récupéré 108724 résultats
# on a récupéré 109212 résultats
# 5000 results collected, making a break
# on a récupéré 109701 résultats
# on a récupéré 110200 résultats
# on a récupéré 110691 résultats
# on a récupéré 111174 résultats
# on a récupéré 111659 résultats
# on a récupéré 112157 résultats
# on a récupéré 112650 résultats
# on a récupéré 113146 résultats
# on a récupéré 113644 résultats
# on a récupéré 114136 résultats
# 5000 results collected, making a break
# on a récupéré 114635 résultats
# on a récupéré 115130 résultats
# on a récupéré 115620 résultats
# on a récupéré 116117 résultats
# on a récupéré 116610 résultats
# on a récupéré 117109 résultats
# on a récupéré 117595 résultats
# on a récupéré 118087 résultats
# on a récupéré 118585 résultats
# on a récupéré 119084 résultats
# 5000 results collected, making a break
# on a récupéré 119582 résultats
# on a récupéré 120079 résultats
# on a récupéré 120576 résultats
# on a récupéré 121073 résultats
# on a récupéré 121563 résultats
# on a récupéré 122060 résultats
# on a récupéré 122560 résultats
# on a récupéré 123058 résultats
# on a récupéré 123557 résultats
# on a récupéré 124054 résultats
# 5000 results collected, making a break
# on a récupéré 124552 résultats
# on a récupéré 125046 résultats
# on a récupéré 125542 résultats
# on a récupéré 126040 résultats
# on a récupéré 126533 résultats
# on a récupéré 127033 résultats
# on a récupéré 127530 résultats
# on a récupéré 128030 résultats
# on a récupéré 128528 résultats
# on a récupéré 129024 résultats
# 5000 results collected, making a break
# on a récupéré 129518 résultats
# on a récupéré 130008 résultats
# on a récupéré 130505 résultats
# on a récupéré 131000 résultats
# on a récupéré 131496 résultats
# on a récupéré 131995 résultats
# on a récupéré 132492 résultats
# on a récupéré 132985 résultats
# on a récupéré 133479 résultats
# on a récupéré 133978 résultats
# 5000 results collected, making a break
# on a récupéré 134472 résultats
# on a récupéré 134971 résultats
# on a récupéré 135469 résultats
# on a récupéré 135964 résultats
# on a récupéré 136461 résultats
# on a récupéré 136956 résultats
# on a récupéré 137453 résultats
# on a récupéré 137952 résultats
# on a récupéré 138452 résultats
# on a récupéré 138948 résultats
# 5000 results collected, making a break
# on a récupéré 139443 résultats
# on a récupéré 139938 résultats
# on a récupéré 140436 résultats
# on a récupéré 140931 résultats
# on a récupéré 141429 résultats
# on a récupéré 141929 résultats
# on a récupéré 142426 résultats
# on a récupéré 142924 résultats
# on a récupéré 143423 résultats
# on a récupéré 143919 résultats
# 5000 results collected, making a break
# on a récupéré 144418 résultats
# on a récupéré 144917 résultats
# on a récupéré 145413 résultats
# on a récupéré 145912 résultats
# on a récupéré 146410 résultats
# on a récupéré 146909 résultats
# on a récupéré 147409 résultats
# on a récupéré 147907 résultats
# on a récupéré 148406 résultats
# on a récupéré 148906 résultats
# 5000 results collected, making a break
# on a récupéré 149404 résultats
# on a récupéré 149900 résultats
# on a récupéré 150396 résultats
# on a récupéré 150887 résultats
# on a récupéré 151386 résultats
# on a récupéré 151882 résultats
# on a récupéré 152380 résultats
# on a récupéré 152879 résultats
# on a récupéré 153379 résultats
# on a récupéré 153879 résultats
# 5000 results collected, making a break
# on a récupéré 154376 résultats
# on a récupéré 154873 résultats
# on a récupéré 155371 résultats
# on a récupéré 155869 résultats
# on a récupéré 156366 résultats
# on a récupéré 156862 résultats
# on a récupéré 157359 résultats
# on a récupéré 157859 résultats
# on a récupéré 158356 résultats
# on a récupéré 158855 résultats
# 5000 results collected, making a break
# on a récupéré 159352 résultats
# on a récupéré 159850 résultats
# on a récupéré 160349 résultats
# on a récupéré 160849 résultats
# on a récupéré 161348 résultats
# on a récupéré 161838 résultats
# on a récupéré 162334 résultats
# on a récupéré 162832 résultats
# on a récupéré 163322 résultats
# on a récupéré 163818 résultats
# 5000 results collected, making a break
# on a récupéré 164316 résultats
# on a récupéré 164813 résultats
# on a récupéré 165310 résultats
# on a récupéré 165808 résultats
# on a récupéré 166306 résultats
# on a récupéré 166757 résultats
# FINI

# %%
for id in [3336943089, 627503827, 493640854, 828290598599872512, 72489273, 2261320772, 2756277147]:
    get_full_user_tweets(id)
# Out:
# on a récupéré 497 résultats
# 5000 results collected, making a break
# on a récupéré 992 résultats
# on a récupéré 1486 résultats
# on a récupéré 1975 résultats
# on a récupéré 2468 résultats
# on a récupéré 2966 résultats
# on a récupéré 3459 résultats
# on a récupéré 3950 résultats
# on a récupéré 4438 résultats
# on a récupéré 4928 résultats
# on a récupéré 5425 résultats
# 5000 results collected, making a break
# on a récupéré 5915 résultats
# on a récupéré 6407 résultats
# on a récupéré 6904 résultats
# on a récupéré 7390 résultats
# on a récupéré 7879 résultats
# on a récupéré 8365 résultats
# on a récupéré 8852 résultats
# on a récupéré 9342 résultats
# on a récupéré 9832 résultats
# on a récupéré 10312 résultats
# 5000 results collected, making a break
# on a récupéré 10795 résultats
# on a récupéré 11283 résultats
# on a récupéré 11765 résultats
# on a récupéré 12249 résultats
# on a récupéré 12738 résultats
# on a récupéré 13217 résultats
# on a récupéré 13697 résultats
# on a récupéré 14173 résultats
# on a récupéré 14659 résultats
# on a récupéré 15148 résultats
# 5000 results collected, making a break
# on a récupéré 15633 résultats
# on a récupéré 16113 résultats
# on a récupéré 16586 résultats
# on a récupéré 17075 résultats
# on a récupéré 17561 résultats
# on a récupéré 18049 résultats
# on a récupéré 18524 résultats
# on a récupéré 18993 résultats
# on a récupéré 19464 résultats
# on a récupéré 19933 résultats
# 5000 results collected, making a break
# on a récupéré 20404 résultats
# on a récupéré 20869 résultats
# on a récupéré 21346 résultats
# on a récupéré 21809 résultats
# on a récupéré 22285 résultats
# on a récupéré 22758 résultats
# on a récupéré 23235 résultats
# on a récupéré 23712 résultats
# on a récupéré 24178 résultats
# on a récupéré 24661 résultats
# 5000 results collected, making a break
# on a récupéré 25134 résultats
# on a récupéré 25615 résultats
# on a récupéré 26073 résultats
# on a récupéré 26545 résultats
# on a récupéré 27009 résultats
# on a récupéré 27476 résultats
# on a récupéré 27945 résultats
# on a récupéré 28421 résultats
# on a récupéré 28895 résultats
# on a récupéré 29362 résultats
# 5000 results collected, making a break
# on a récupéré 29828 résultats
# on a récupéré 30288 résultats
# on a récupéré 30754 résultats
# on a récupéré 31225 résultats
# on a récupéré 31702 résultats
# on a récupéré 32178 résultats
# on a récupéré 32651 résultats
# on a récupéré 33137 résultats
# on a récupéré 33617 résultats
# on a récupéré 34097 résultats
# 5000 results collected, making a break
# on a récupéré 34560 résultats
# on a récupéré 35033 résultats
# on a récupéré 35503 résultats
# on a récupéré 35974 résultats
# on a récupéré 36441 résultats
# on a récupéré 36916 résultats
# on a récupéré 37395 résultats
# on a récupéré 37869 résultats
# on a récupéré 38350 résultats
# on a récupéré 38830 résultats
# 5000 results collected, making a break
# on a récupéré 39307 résultats
# on a récupéré 39775 résultats
# on a récupéré 40229 résultats
# on a récupéré 40686 résultats
# on a récupéré 41148 résultats
# on a récupéré 41612 résultats
# on a récupéré 42055 résultats
# on a récupéré 42526 résultats
# on a récupéré 42994 résultats
# on a récupéré 43461 résultats
# 5000 results collected, making a break
# on a récupéré 43933 résultats
# on a récupéré 44407 résultats
# on a récupéré 44853 résultats
# on a récupéré 45322 résultats
# on a récupéré 45776 résultats
# on a récupéré 46247 résultats
# on a récupéré 46709 résultats
# on a récupéré 47167 résultats
# on a récupéré 47615 résultats
# on a récupéré 48070 résultats
# 5000 results collected, making a break
# on a récupéré 48551 résultats
# on a récupéré 49024 résultats
# on a récupéré 49488 résultats
# on a récupéré 49957 résultats
# on a récupéré 50418 résultats
# on a récupéré 50889 résultats
# on a récupéré 51336 résultats
# on a récupéré 51805 résultats
# on a récupéré 52273 résultats
# on a récupéré 52749 résultats
# 5000 results collected, making a break
# on a récupéré 53225 résultats
# on a récupéré 53696 résultats
# on a récupéré 54167 résultats
# on a récupéré 54633 résultats
# on a récupéré 55099 résultats
# on a récupéré 55559 résultats
# on a récupéré 56029 résultats
# on a récupéré 56486 résultats
# on a récupéré 56961 résultats
# on a récupéré 57434 résultats
# 5000 results collected, making a break
# on a récupéré 57908 résultats
# on a récupéré 58378 résultats
# on a récupéré 58841 résultats
# on a récupéré 59321 résultats
# on a récupéré 59783 résultats
# on a récupéré 60249 résultats
# on a récupéré 60712 résultats
# on a récupéré 61193 résultats
# on a récupéré 61654 résultats
# on a récupéré 62107 résultats
# 5000 results collected, making a break
# on a récupéré 62567 résultats
# on a récupéré 63009 résultats
# on a récupéré 63451 résultats
# on a récupéré 63905 résultats
# on a récupéré 64376 résultats
# on a récupéré 64859 résultats
# on a récupéré 65309 résultats
# on a récupéré 65782 résultats
# on a récupéré 66248 résultats
# on a récupéré 66705 résultats
# 5000 results collected, making a break
# on a récupéré 67142 résultats
# on a récupéré 67590 résultats
# on a récupéré 68052 résultats
# on a récupéré 68521 résultats
# on a récupéré 68979 résultats
# on a récupéré 69451 résultats
# on a récupéré 69915 résultats
# on a récupéré 70381 résultats
# on a récupéré 70826 résultats
# on a récupéré 71290 résultats
# 5000 results collected, making a break
# on a récupéré 71759 résultats
# on a récupéré 72234 résultats
# on a récupéré 72704 résultats
# on a récupéré 73169 résultats
# on a récupéré 73640 résultats
# on a récupéré 74112 résultats
# on a récupéré 74579 résultats
# on a récupéré 75058 résultats
# on a récupéré 75541 résultats
# on a récupéré 76024 résultats
# 5000 results collected, making a break
# on a récupéré 76498 résultats
# on a récupéré 76969 résultats
# on a récupéré 77446 résultats
# on a récupéré 77918 résultats
# on a récupéré 78404 résultats
# on a récupéré 78888 résultats
# on a récupéré 79367 résultats
# on a récupéré 79845 résultats
# on a récupéré 80316 résultats
# on a récupéré 80804 résultats
# 5000 results collected, making a break
# on a récupéré 81287 résultats
# on a récupéré 81770 résultats
# on a récupéré 82248 résultats
# on a récupéré 82729 résultats
# on a récupéré 83210 résultats
# on a récupéré 83691 résultats
# on a récupéré 84172 résultats
# on a récupéré 84650 résultats
# on a récupéré 85128 résultats
# on a récupéré 85604 résultats
# 5000 results collected, making a break
# on a récupéré 86073 résultats
# on a récupéré 86545 résultats
# on a récupéré 87020 résultats
# on a récupéré 87491 résultats
# on a récupéré 87969 résultats
# on a récupéré 88436 résultats
# on a récupéré 88912 résultats
# on a récupéré 89384 résultats
# on a récupéré 89860 résultats
# on a récupéré 90348 résultats
# 5000 results collected, making a break
# on a récupéré 90812 résultats
# on a récupéré 91276 résultats
# on a récupéré 91730 résultats
# on a récupéré 92189 résultats
# on a récupéré 92651 résultats
# on a récupéré 93117 résultats
# on a récupéré 93591 résultats
# on a récupéré 94057 résultats
# on a récupéré 94519 résultats
# on a récupéré 94984 résultats
# 5000 results collected, making a break
# on a récupéré 95436 résultats
# on a récupéré 95896 résultats
# on a récupéré 96349 résultats
# on a récupéré 96802 résultats
# on a récupéré 97275 résultats
# on a récupéré 97683 résultats
# on a récupéré 98148 résultats
# on a récupéré 98594 résultats
# on a récupéré 99052 résultats
# on a récupéré 99523 résultats
# 5000 results collected, making a break
# on a récupéré 99987 résultats
# on a récupéré 100466 résultats
# on a récupéré 100903 résultats
# on a récupéré 101378 résultats
# on a récupéré 101855 résultats
# on a récupéré 102338 résultats
# on a récupéré 102813 résultats
# on a récupéré 103299 résultats
# on a récupéré 103790 résultats
# on a récupéré 104280 résultats
# 5000 results collected, making a break
# on a récupéré 104772 résultats
# on a récupéré 105255 résultats
# on a récupéré 105744 résultats
# on a récupéré 106234 résultats
# on a récupéré 106715 résultats
# on a récupéré 107195 résultats
# on a récupéré 107672 résultats
# on a récupéré 108155 résultats
# on a récupéré 108636 résultats
# on a récupéré 109110 résultats
# 5000 results collected, making a break
# on a récupéré 109598 résultats
# on a récupéré 110086 résultats
# on a récupéré 110563 résultats
# FINI
# on a récupéré 493 résultats
# 5000 results collected, making a break
# on a récupéré 979 résultats
# on a récupéré 1464 résultats
# on a récupéré 1955 résultats
# on a récupéré 2433 résultats
# on a récupéré 2920 résultats
# on a récupéré 3413 résultats
# on a récupéré 3910 résultats
# on a récupéré 4402 résultats
# on a récupéré 4896 résultats
# on a récupéré 5387 résultats
# 5000 results collected, making a break
# on a récupéré 5875 résultats
# on a récupéré 6365 résultats
# on a récupéré 6854 résultats
# on a récupéré 7347 résultats
# on a récupéré 7833 résultats
# on a récupéré 8326 résultats
# on a récupéré 8813 résultats
# on a récupéré 9301 résultats
# on a récupéré 9792 résultats
# on a récupéré 10286 résultats
# 5000 results collected, making a break
# on a récupéré 10777 résultats
# on a récupéré 11267 résultats
# on a récupéré 11753 résultats
# on a récupéré 12244 résultats
# on a récupéré 12729 résultats
# on a récupéré 13214 résultats
# on a récupéré 13696 résultats
# on a récupéré 14188 résultats
# on a récupéré 14676 résultats
# on a récupéré 15169 résultats
# 5000 results collected, making a break
# on a récupéré 15657 résultats
# on a récupéré 16145 résultats
# on a récupéré 16632 résultats
# on a récupéré 17121 résultats
# on a récupéré 17609 résultats
# on a récupéré 18099 résultats
# on a récupéré 18585 résultats
# on a récupéré 19076 résultats
# on a récupéré 19559 résultats
# on a récupéré 20046 résultats
# 5000 results collected, making a break
# on a récupéré 20535 résultats
# on a récupéré 21016 résultats
# on a récupéré 21503 résultats
# on a récupéré 21991 résultats
# on a récupéré 22486 résultats
# on a récupéré 22984 résultats
# on a récupéré 23478 résultats
# on a récupéré 23974 résultats
# on a récupéré 24465 résultats
# on a récupéré 24963 résultats
# 5000 results collected, making a break
# on a récupéré 25463 résultats
# on a récupéré 25962 résultats
# on a récupéré 26460 résultats
# on a récupéré 26960 résultats
# on a récupéré 27460 résultats
# on a récupéré 27959 résultats
# on a récupéré 28459 résultats
# on a récupéré 28959 résultats
# on a récupéré 29459 résultats
# on a récupéré 29959 résultats
# 5000 results collected, making a break
# on a récupéré 30459 résultats
# on a récupéré 30959 résultats
# on a récupéré 31459 résultats
# on a récupéré 31959 résultats
# on a récupéré 32455 résultats
# on a récupéré 32954 résultats
# on a récupéré 33453 résultats
# on a récupéré 33953 résultats
# on a récupéré 34452 résultats
# on a récupéré 34952 résultats
# 5000 results collected, making a break
# on a récupéré 35452 résultats
# on a récupéré 35952 résultats
# on a récupéré 36452 résultats
# on a récupéré 36952 résultats
# on a récupéré 37452 résultats
# on a récupéré 37952 résultats
# on a récupéré 38452 résultats
# on a récupéré 38635 résultats
# FINI
# on a récupéré 495 résultats
# 5000 results collected, making a break
# on a récupéré 990 résultats
# on a récupéré 1486 résultats
# on a récupéré 1981 résultats
# on a récupéré 2471 résultats
# on a récupéré 2951 résultats
# on a récupéré 3429 résultats
# on a récupéré 3908 résultats
# on a récupéré 4406 résultats
# on a récupéré 4896 résultats
# on a récupéré 5390 résultats
# 5000 results collected, making a break
# on a récupéré 5882 résultats
# on a récupéré 6374 résultats
# on a récupéré 6859 résultats
# on a récupéré 7339 résultats
# on a récupéré 7828 résultats
# on a récupéré 8312 résultats
# on a récupéré 8805 résultats
# on a récupéré 9294 résultats
# on a récupéré 9788 résultats
# on a récupéré 10279 résultats
# 5000 results collected, making a break
# on a récupéré 10770 résultats
# on a récupéré 11255 résultats
# on a récupéré 11745 résultats
# on a récupéré 12237 résultats
# on a récupéré 12727 résultats
# on a récupéré 13219 résultats
# on a récupéré 13712 résultats
# on a récupéré 14193 résultats
# on a récupéré 14682 résultats
# on a récupéré 15169 résultats
# 5000 results collected, making a break
# on a récupéré 15650 résultats
# on a récupéré 16121 résultats
# on a récupéré 16612 résultats
# on a récupéré 17102 résultats
# on a récupéré 17584 résultats
# on a récupéré 18071 résultats
# on a récupéré 18562 résultats
# on a récupéré 19042 résultats
# on a récupéré 19527 résultats
# on a récupéré 20010 résultats
# 5000 results collected, making a break
# on a récupéré 20495 résultats
# on a récupéré 20982 résultats
# on a récupéré 21463 résultats
# on a récupéré 21944 résultats
# on a récupéré 22414 résultats
# on a récupéré 22895 résultats
# on a récupéré 23374 résultats
# on a récupéré 23860 résultats
# on a récupéré 24343 résultats
# on a récupéré 24824 résultats
# 5000 results collected, making a break
# on a récupéré 25305 résultats
# on a récupéré 25779 résultats
# on a récupéré 26266 résultats
# on a récupéré 26754 résultats
# on a récupéré 27241 résultats
# on a récupéré 27726 résultats
# on a récupéré 28216 résultats
# on a récupéré 28686 résultats
# on a récupéré 29173 résultats
# on a récupéré 29653 résultats
# 5000 results collected, making a break
# on a récupéré 30136 résultats
# on a récupéré 30613 résultats
# on a récupéré 31102 résultats
# on a récupéré 31589 résultats
# on a récupéré 32074 résultats
# on a récupéré 32561 résultats
# on a récupéré 33053 résultats
# on a récupéré 33538 résultats
# on a récupéré 34026 résultats
# on a récupéré 34519 résultats
# 5000 results collected, making a break
# on a récupéré 34999 résultats
# on a récupéré 35484 résultats
# on a récupéré 35978 résultats
# on a récupéré 36470 résultats
# on a récupéré 36957 résultats
# on a récupéré 37438 résultats
# on a récupéré 37931 résultats
# on a récupéré 38423 résultats
# on a récupéré 38912 résultats
# on a récupéré 39399 résultats
# 5000 results collected, making a break
# on a récupéré 39888 résultats
# on a récupéré 40374 résultats
# on a récupéré 40848 résultats
# on a récupéré 41336 résultats
# on a récupéré 41828 résultats
# on a récupéré 42312 résultats
# on a récupéré 42799 résultats
# on a récupéré 43282 résultats
# on a récupéré 43774 résultats
# on a récupéré 44266 résultats
# 5000 results collected, making a break
# on a récupéré 44742 résultats
# on a récupéré 45226 résultats
# on a récupéré 45706 résultats
# on a récupéré 46183 résultats
# on a récupéré 46670 résultats
# on a récupéré 47155 résultats
# on a récupéré 47642 résultats
# on a récupéré 48118 résultats
# on a récupéré 48596 résultats
# on a récupéré 49081 résultats
# 5000 results collected, making a break
# on a récupéré 49559 résultats
# on a récupéré 50037 résultats
# on a récupéré 50514 résultats
# on a récupéré 50991 résultats
# on a récupéré 51465 résultats
# on a récupéré 51943 résultats
# on a récupéré 52419 résultats
# on a récupéré 52888 résultats
# on a récupéré 53372 résultats
# on a récupéré 53853 résultats
# 5000 results collected, making a break
# on a récupéré 54337 résultats
# on a récupéré 54820 résultats
# on a récupéré 55312 résultats
# on a récupéré 55350 résultats
# FINI
# on a récupéré 0 résultats
# aucun résultat pour cette requête, l"id est peut etre invalide: 828290598599872512
# 5000 results collected, making a break
# FINI
# on a récupéré 491 résultats
# 5000 results collected, making a break
# on a récupéré 979 résultats
# on a récupéré 1471 résultats
# on a récupéré 1965 résultats
# on a récupéré 2464 résultats
# on a récupéré 2950 résultats
# on a récupéré 3444 résultats
# on a récupéré 3939 résultats
# on a récupéré 4432 résultats
# on a récupéré 4927 résultats
# on a récupéré 5421 résultats
# 5000 results collected, making a break
# on a récupéré 5912 résultats
# on a récupéré 6401 résultats
# on a récupéré 6893 résultats
# on a récupéré 7386 résultats
# on a récupéré 7880 résultats
# on a récupéré 8378 résultats
# on a récupéré 8872 résultats
# on a récupéré 9364 résultats
# on a récupéré 9860 résultats
# on a récupéré 10352 résultats
# 5000 results collected, making a break
# on a récupéré 10848 résultats
# on a récupéré 11338 résultats
# on a récupéré 11836 résultats
# on a récupéré 12335 résultats
# on a récupéré 12833 résultats
# on a récupéré 13326 résultats
# on a récupéré 13821 résultats
# on a récupéré 14317 résultats
# on a récupéré 14812 résultats
# on a récupéré 15302 résultats
# 5000 results collected, making a break
# on a récupéré 15795 résultats
# on a récupéré 16286 résultats
# on a récupéré 16781 résultats
# on a récupéré 17270 résultats
# on a récupéré 17762 résultats
# on a récupéré 18250 résultats
# on a récupéré 18745 résultats
# on a récupéré 19241 résultats
# on a récupéré 19738 résultats
# on a récupéré 20230 résultats
# 5000 results collected, making a break
# on a récupéré 20716 résultats
# on a récupéré 21208 résultats
# on a récupéré 21703 résultats
# on a récupéré 22196 résultats
# on a récupéré 22690 résultats
# on a récupéré 23183 résultats
# on a récupéré 23672 résultats
# on a récupéré 24170 résultats
# on a récupéré 24659 résultats
# on a récupéré 25158 résultats
# 5000 results collected, making a break
# on a récupéré 25654 résultats
# on a récupéré 26150 résultats
# on a récupéré 26646 résultats
# on a récupéré 27137 résultats
# on a récupéré 27628 résultats
# on a récupéré 28122 résultats
# on a récupéré 28614 résultats
# on a récupéré 29100 résultats
# on a récupéré 29581 résultats
# on a récupéré 30067 résultats
# 5000 results collected, making a break
# on a récupéré 30549 résultats
# on a récupéré 31032 résultats
# on a récupéré 31516 résultats
# on a récupéré 32007 résultats
# on a récupéré 32499 résultats
# on a récupéré 32987 résultats
# on a récupéré 33481 résultats
# on a récupéré 33975 résultats
# on a récupéré 34473 résultats
# on a récupéré 34968 résultats
# 5000 results collected, making a break
# on a récupéré 35462 résultats
# on a récupéré 35953 résultats
# on a récupéré 36452 résultats
# on a récupéré 36943 résultats
# on a récupéré 37427 résultats
# on a récupéré 37925 résultats
# on a récupéré 38420 résultats
# on a récupéré 38916 résultats
# on a récupéré 39410 résultats
# on a récupéré 39902 résultats
# 5000 results collected, making a break
# on a récupéré 40392 résultats
# on a récupéré 40885 résultats
# on a récupéré 41369 résultats
# on a récupéré 41858 résultats
# on a récupéré 42346 résultats
# on a récupéré 42838 résultats
# on a récupéré 43333 résultats
# on a récupéré 43825 résultats
# on a récupéré 44321 résultats
# on a récupéré 44817 résultats
# 5000 results collected, making a break
# on a récupéré 45312 résultats
# on a récupéré 45801 résultats
# on a récupéré 46294 résultats
# on a récupéré 46789 résultats
# on a récupéré 47283 résultats
# on a récupéré 47773 résultats
# on a récupéré 48260 résultats
# on a récupéré 48752 résultats
# on a récupéré 49243 résultats
# on a récupéré 49740 résultats
# 5000 results collected, making a break
# on a récupéré 50233 résultats
# on a récupéré 50725 résultats
# on a récupéré 51221 résultats
# on a récupéré 51713 résultats
# on a récupéré 52208 résultats
# on a récupéré 52695 résultats
# on a récupéré 53179 résultats
# on a récupéré 53663 résultats
# on a récupéré 54154 résultats
# on a récupéré 54645 résultats
# 5000 results collected, making a break
# on a récupéré 55133 résultats
# on a récupéré 55627 résultats
# on a récupéré 56124 résultats
# on a récupéré 56619 résultats
# on a récupéré 57106 résultats
# on a récupéré 57599 résultats
# on a récupéré 58091 résultats
# on a récupéré 58584 résultats
# on a récupéré 59081 résultats
# on a récupéré 59575 résultats
# 5000 results collected, making a break
# on a récupéré 60071 résultats
# on a récupéré 60564 résultats
# on a récupéré 61054 résultats
# on a récupéré 61551 résultats
# on a récupéré 62047 résultats
# on a récupéré 62543 résultats
# on a récupéré 63040 résultats
# on a récupéré 63533 résultats
# on a récupéré 64023 résultats
# on a récupéré 64515 résultats
# 5000 results collected, making a break
# on a récupéré 65008 résultats
# on a récupéré 65506 résultats
# on a récupéré 65999 résultats
# on a récupéré 66495 résultats
# on a récupéré 66990 résultats
# on a récupéré 67485 résultats
# on a récupéré 67979 résultats
# on a récupéré 68469 résultats
# on a récupéré 68965 résultats
# on a récupéré 69458 résultats
# 5000 results collected, making a break
# on a récupéré 69951 résultats
# on a récupéré 70441 résultats
# on a récupéré 70932 résultats
# on a récupéré 71416 résultats
# on a récupéré 71909 résultats
# on a récupéré 72403 résultats
# on a récupéré 72890 résultats
# on a récupéré 73385 résultats
# on a récupéré 73881 résultats
# on a récupéré 74372 résultats
# 5000 results collected, making a break
# on a récupéré 74867 résultats
# on a récupéré 75359 résultats
# on a récupéré 75850 résultats
# on a récupéré 76346 résultats
# on a récupéré 76835 résultats
# on a récupéré 77326 résultats
# on a récupéré 77818 résultats
# on a récupéré 78310 résultats
# on a récupéré 78803 résultats
# on a récupéré 79287 résultats
# 5000 results collected, making a break
# on a récupéré 79776 résultats
# on a récupéré 80263 résultats
# on a récupéré 80746 résultats
# on a récupéré 81236 résultats
# on a récupéré 81727 résultats
# on a récupéré 82207 résultats
# on a récupéré 82702 résultats
# on a récupéré 83190 résultats
# on a récupéré 83681 résultats
# on a récupéré 84172 résultats
# 5000 results collected, making a break
# on a récupéré 84662 résultats
# on a récupéré 85153 résultats
# on a récupéré 85644 résultats
# on a récupéré 86133 résultats
# on a récupéré 86618 résultats
# on a récupéré 87101 résultats
# on a récupéré 87585 résultats
# on a récupéré 88066 résultats
# on a récupéré 88543 résultats
# on a récupéré 89033 résultats
# 5000 results collected, making a break
# on a récupéré 89515 résultats
# on a récupéré 89999 résultats
# on a récupéré 90486 résultats
# on a récupéré 90973 résultats
# on a récupéré 91457 résultats
# on a récupéré 91937 résultats
# on a récupéré 92428 résultats
# on a récupéré 92913 résultats
# on a récupéré 93401 résultats
# on a récupéré 93885 résultats
# 5000 results collected, making a break
# on a récupéré 94372 résultats
# on a récupéré 94856 résultats
# on a récupéré 95320 résultats
# on a récupéré 95774 résultats
# on a récupéré 96205 résultats
# on a récupéré 96625 résultats
# on a récupéré 97101 résultats
# on a récupéré 97339 résultats
# FINI
# on a récupéré 500 résultats
# 5000 results collected, making a break
# on a récupéré 996 résultats
# on a récupéré 1492 résultats
# on a récupéré 1989 résultats
# on a récupéré 2482 résultats
# on a récupéré 2978 résultats
# on a récupéré 3466 résultats
# on a récupéré 3958 résultats
# on a récupéré 4451 résultats
# on a récupéré 4930 résultats
# on a récupéré 5414 résultats
# 5000 results collected, making a break
# on a récupéré 5896 résultats
# on a récupéré 6381 résultats
# on a récupéré 6868 résultats
# on a récupéré 7352 résultats
# on a récupéré 7839 résultats
# on a récupéré 8320 résultats
# on a récupéré 8804 résultats
# on a récupéré 9292 résultats
# on a récupéré 9782 résultats
# on a récupéré 10275 résultats
# 5000 results collected, making a break
# on a récupéré 10762 résultats
# on a récupéré 11235 résultats
# on a récupéré 11721 résultats
# on a récupéré 12213 résultats
# on a récupéré 12704 résultats
# on a récupéré 13189 résultats
# on a récupéré 13661 résultats
# on a récupéré 14150 résultats
# on a récupéré 14630 résultats
# on a récupéré 15114 résultats
# 5000 results collected, making a break
# on a récupéré 15600 résultats
# on a récupéré 16087 résultats
# on a récupéré 16565 résultats
# on a récupéré 17051 résultats
# on a récupéré 17538 résultats
# on a récupéré 18010 résultats
# on a récupéré 18501 résultats
# on a récupéré 18982 résultats
# on a récupéré 19467 résultats
# on a récupéré 19941 résultats
# 5000 results collected, making a break
# on a récupéré 20425 résultats
# on a récupéré 20897 résultats
# on a récupéré 21371 résultats
# on a récupéré 21854 résultats
# on a récupéré 22341 résultats
# on a récupéré 22824 résultats
# on a récupéré 23308 résultats
# on a récupéré 23785 résultats
# on a récupéré 24276 résultats
# on a récupéré 24762 résultats
# 5000 results collected, making a break
# on a récupéré 25240 résultats
# on a récupéré 25722 résultats
# on a récupéré 26208 résultats
# on a récupéré 26678 résultats
# on a récupéré 27158 résultats
# on a récupéré 27628 résultats
# on a récupéré 28104 résultats
# on a récupéré 28578 résultats
# on a récupéré 29063 résultats
# on a récupéré 29550 résultats
# 5000 results collected, making a break
# on a récupéré 30032 résultats
# on a récupéré 30515 résultats
# on a récupéré 30990 résultats
# on a récupéré 31461 résultats
# on a récupéré 31943 résultats
# on a récupéré 32419 résultats
# on a récupéré 32890 résultats
# on a récupéré 33359 résultats
# on a récupéré 33833 résultats
# on a récupéré 34298 résultats
# 5000 results collected, making a break
# on a récupéré 34773 résultats
# on a récupéré 35254 résultats
# on a récupéré 35719 résultats
# on a récupéré 36194 résultats
# on a récupéré 36654 résultats
# on a récupéré 37131 résultats
# on a récupéré 37608 résultats
# on a récupéré 38092 résultats
# on a récupéré 38577 résultats
# on a récupéré 39054 résultats
# 5000 results collected, making a break
# on a récupéré 39514 résultats
# on a récupéré 39984 résultats
# on a récupéré 40448 résultats
# on a récupéré 40932 résultats
# on a récupéré 41415 résultats
# on a récupéré 41886 résultats
# on a récupéré 42367 résultats
# on a récupéré 42831 résultats
# on a récupéré 43308 résultats
# on a récupéré 43786 résultats
# 5000 results collected, making a break
# on a récupéré 44255 résultats
# on a récupéré 44730 résultats
# on a récupéré 45195 résultats
# on a récupéré 45670 résultats
# on a récupéré 46139 résultats
# on a récupéré 46614 résultats
# on a récupéré 47104 résultats
# on a récupéré 47585 résultats
# on a récupéré 48055 résultats
# on a récupéré 48537 résultats
# 5000 results collected, making a break
# on a récupéré 49021 résultats
# on a récupéré 49504 résultats
# on a récupéré 49969 résultats
# on a récupéré 50449 résultats
# on a récupéré 50918 résultats
# on a récupéré 51391 résultats
# on a récupéré 51862 résultats
# on a récupéré 52341 résultats
# on a récupéré 52821 résultats
# on a récupéré 53306 résultats
# 5000 results collected, making a break
# on a récupéré 53788 résultats
# on a récupéré 54261 résultats
# on a récupéré 54746 résultats
# on a récupéré 55225 résultats
# on a récupéré 55691 résultats
# on a récupéré 56162 résultats
# on a récupéré 56648 résultats
# on a récupéré 57138 résultats
# on a récupéré 57619 résultats
# on a récupéré 58094 résultats
# 5000 results collected, making a break
# on a récupéré 58579 résultats
# on a récupéré 59060 résultats
# on a récupéré 59539 résultats
# on a récupéré 60019 résultats
# on a récupéré 60492 résultats
# on a récupéré 60964 résultats
# on a récupéré 61446 résultats
# on a récupéré 61930 résultats
# on a récupéré 62400 résultats
# on a récupéré 62888 résultats
# 5000 results collected, making a break
# on a récupéré 63353 résultats
# on a récupéré 63832 résultats
# on a récupéré 64316 résultats
# on a récupéré 64797 résultats
# on a récupéré 65281 résultats
# on a récupéré 65765 résultats
# on a récupéré 66252 résultats
# on a récupéré 66744 résultats
# on a récupéré 67227 résultats
# on a récupéré 67700 résultats
# 5000 results collected, making a break
# on a récupéré 68185 résultats
# on a récupéré 68655 résultats
# on a récupéré 69133 résultats
# on a récupéré 69613 résultats
# on a récupéré 70082 résultats
# on a récupéré 70562 résultats
# on a récupéré 71033 résultats
# on a récupéré 71513 résultats
# on a récupéré 71994 résultats
# on a récupéré 72469 résultats
# 5000 results collected, making a break
# on a récupéré 72952 résultats
# on a récupéré 73425 résultats
# on a récupéré 73890 résultats
# on a récupéré 74377 résultats
# on a récupéré 74862 résultats
# on a récupéré 75340 résultats
# on a récupéré 75818 résultats
# on a récupéré 76305 résultats
# on a récupéré 76779 résultats
# on a récupéré 77269 résultats
# 5000 results collected, making a break
# on a récupéré 77748 résultats
# on a récupéré 78241 résultats
# on a récupéré 78727 résultats
# on a récupéré 79215 résultats
# on a récupéré 79709 résultats
# on a récupéré 80197 résultats
# on a récupéré 80679 résultats
# on a récupéré 81174 résultats
# on a récupéré 81652 résultats
# on a récupéré 82138 résultats
# 5000 results collected, making a break
# on a récupéré 82633 résultats
# on a récupéré 83118 résultats
# on a récupéré 83593 résultats
# on a récupéré 84083 résultats
# on a récupéré 84567 résultats
# on a récupéré 85056 résultats
# on a récupéré 85540 résultats
# on a récupéré 86033 résultats
# on a récupéré 86521 résultats
# on a récupéré 87004 résultats
# 5000 results collected, making a break
# on a récupéré 87490 résultats
# on a récupéré 87975 résultats
# on a récupéré 88459 résultats
# on a récupéré 88938 résultats
# on a récupéré 89424 résultats
# on a récupéré 89909 résultats
# on a récupéré 90390 résultats
# on a récupéré 90871 résultats
# on a récupéré 91362 résultats
# on a récupéré 91843 résultats
# 5000 results collected, making a break
# on a récupéré 92336 résultats
# on a récupéré 92830 résultats
# on a récupéré 93317 résultats
# on a récupéré 93802 résultats
# on a récupéré 94293 résultats
# on a récupéré 94778 résultats
# on a récupéré 95266 résultats
# on a récupéré 95747 résultats
# on a récupéré 96227 résultats
# on a récupéré 96716 résultats
# 5000 results collected, making a break
# on a récupéré 97197 résultats
# on a récupéré 97685 résultats
# on a récupéré 98176 résultats
# on a récupéré 98662 résultats
# on a récupéré 99143 résultats
# on a récupéré 99630 résultats
# on a récupéré 100114 résultats
# on a récupéré 100601 résultats
# on a récupéré 101083 résultats
# on a récupéré 101555 résultats
# 5000 results collected, making a break
# on a récupéré 102033 résultats
# on a récupéré 102511 résultats
# on a récupéré 102996 résultats
# on a récupéré 103483 résultats
# on a récupéré 103967 résultats
# on a récupéré 104456 résultats
# on a récupéré 104941 résultats
# on a récupéré 105419 résultats
# on a récupéré 105901 résultats
# on a récupéré 106389 résultats
# 5000 results collected, making a break
# on a récupéré 106871 résultats
# on a récupéré 107344 résultats
# on a récupéré 107830 résultats
# on a récupéré 108308 résultats
# on a récupéré 108787 résultats
# on a récupéré 109277 résultats
# on a récupéré 109754 résultats
# on a récupéré 110244 résultats
# on a récupéré 110732 résultats
# on a récupéré 111203 résultats
# 5000 results collected, making a break
# on a récupéré 111694 résultats
# on a récupéré 112177 résultats
# on a récupéré 112658 résultats
# on a récupéré 113140 résultats
# on a récupéré 113629 résultats
# on a récupéré 114119 résultats
# on a récupéré 114610 résultats
# on a récupéré 115097 résultats
# on a récupéré 115583 résultats
# on a récupéré 116063 résultats
# 5000 results collected, making a break
# on a récupéré 116542 résultats
# on a récupéré 117032 résultats
# on a récupéré 117517 résultats
# on a récupéré 117995 résultats
# on a récupéré 118476 résultats
# on a récupéré 118952 résultats
# on a récupéré 119431 résultats
# on a récupéré 119908 résultats
# on a récupéré 120389 résultats
# on a récupéré 120869 résultats
# 5000 results collected, making a break
# on a récupéré 121335 résultats
# on a récupéré 121810 résultats
# on a récupéré 122285 résultats
# on a récupéré 122764 résultats
# on a récupéré 123231 résultats
# on a récupéré 123709 résultats
# on a récupéré 124189 résultats
# on a récupéré 124654 résultats
# on a récupéré 125123 résultats
# on a récupéré 125600 résultats
# 5000 results collected, making a break
# on a récupéré 126084 résultats
# on a récupéré 126562 résultats
# on a récupéré 127039 résultats
# on a récupéré 127522 résultats
# on a récupéré 128007 résultats
# on a récupéré 128494 résultats
# on a récupéré 128987 résultats
# on a récupéré 129465 résultats
# on a récupéré 129944 résultats
# on a récupéré 130428 résultats
# 5000 results collected, making a break
# on a récupéré 130909 résultats
# on a récupéré 131383 résultats
# on a récupéré 131864 résultats
# on a récupéré 132339 résultats
# on a récupéré 132821 résultats
# on a récupéré 133309 résultats
# on a récupéré 133791 résultats
# on a récupéré 134274 résultats
# on a récupéré 134761 résultats
# on a récupéré 135235 résultats
# 5000 results collected, making a break
# on a récupéré 135722 résultats
# on a récupéré 136205 résultats
# on a récupéré 136685 résultats
# on a récupéré 137163 résultats
# on a récupéré 137650 résultats
# on a récupéré 138131 résultats
# on a récupéré 138609 résultats
# on a récupéré 139094 résultats
# on a récupéré 139583 résultats
# on a récupéré 140059 résultats
# 5000 results collected, making a break
# on a récupéré 140544 résultats
# on a récupéré 141035 résultats
# on a récupéré 141521 résultats
# on a récupéré 142006 résultats
# on a récupéré 142494 résultats
# on a récupéré 142984 résultats
# on a récupéré 143471 résultats
# on a récupéré 143960 résultats
# on a récupéré 144442 résultats
# on a récupéré 144920 résultats
# 5000 results collected, making a break
# on a récupéré 145410 résultats
# on a récupéré 145896 résultats
# on a récupéré 146388 résultats
# on a récupéré 146874 résultats
# on a récupéré 147367 résultats
# on a récupéré 147851 résultats
# on a récupéré 148337 résultats
# on a récupéré 148815 résultats
# on a récupéré 149302 résultats
# on a récupéré 149792 résultats
# 5000 results collected, making a break
# on a récupéré 150274 résultats
# on a récupéré 150764 résultats
# on a récupéré 151245 résultats
# on a récupéré 151730 résultats
# on a récupéré 152210 résultats
# on a récupéré 152696 résultats
# on a récupéré 153176 résultats
# on a récupéré 153661 résultats
# on a récupéré 154150 résultats
# on a récupéré 154639 résultats
# 5000 results collected, making a break
# on a récupéré 155126 résultats
# on a récupéré 155609 résultats
# on a récupéré 156091 résultats
# on a récupéré 156575 résultats
# on a récupéré 157051 résultats
# on a récupéré 157538 résultats
# on a récupéré 158012 résultats
# on a récupéré 158493 résultats
# on a récupéré 158972 résultats
# on a récupéré 159455 résultats
# 5000 results collected, making a break
# on a récupéré 159937 résultats
# on a récupéré 160407 résultats
# on a récupéré 160870 résultats
# on a récupéré 161362 résultats
# on a récupéré 161850 résultats
# on a récupéré 162332 résultats
# on a récupéré 162825 résultats
# on a récupéré 163310 résultats
# on a récupéré 163791 résultats
# on a récupéré 164279 résultats
# 5000 results collected, making a break
# on a récupéré 164773 résultats
# on a récupéré 165256 résultats
# on a récupéré 165737 résultats
# on a récupéré 166221 résultats
# on a récupéré 166712 résultats
# on a récupéré 167192 résultats
# on a récupéré 167680 résultats
# on a récupéré 168153 résultats
# on a récupéré 168646 résultats
# on a récupéré 169138 résultats
# 5000 results collected, making a break
# on a récupéré 169625 résultats
# on a récupéré 170116 résultats
# on a récupéré 170598 résultats
# on a récupéré 171086 résultats
# on a récupéré 171575 résultats
# on a récupéré 172066 résultats
# on a récupéré 172559 résultats
# on a récupéré 173051 résultats
# on a récupéré 173543 résultats
# on a récupéré 174032 résultats
# 5000 results collected, making a break
# on a récupéré 174522 résultats
# on a récupéré 175015 résultats
# on a récupéré 175504 résultats
# on a récupéré 175991 résultats
# on a récupéré 176472 résultats
# on a récupéré 176961 résultats
# on a récupéré 177446 résultats
# on a récupéré 177939 résultats
# on a récupéré 178422 résultats
# on a récupéré 178907 résultats
# 5000 results collected, making a break
# on a récupéré 179392 résultats
# on a récupéré 179881 résultats
# on a récupéré 180371 résultats
# on a récupéré 180850 résultats
# on a récupéré 181329 résultats
# on a récupéré 181810 résultats
# on a récupéré 182298 résultats
# on a récupéré 182788 résultats
# on a récupéré 183276 résultats
# on a récupéré 183756 résultats
# 5000 results collected, making a break
# on a récupéré 184240 résultats
# on a récupéré 184731 résultats
# on a récupéré 185217 résultats
# on a récupéré 185699 résultats
# on a récupéré 186191 résultats
# on a récupéré 186677 résultats
# on a récupéré 187161 résultats
# on a récupéré 187651 résultats
# on a récupéré 188139 résultats
# on a récupéré 188617 résultats
# 5000 results collected, making a break
# on a récupéré 189103 résultats
# on a récupéré 189587 résultats
# on a récupéré 190067 résultats
# on a récupéré 190550 résultats
# on a récupéré 191040 résultats
# on a récupéré 191527 résultats
# on a récupéré 192011 résultats
# on a récupéré 192498 résultats
# on a récupéré 192976 résultats
# on a récupéré 193458 résultats
# 5000 results collected, making a break
# on a récupéré 193933 résultats
# on a récupéré 194419 résultats
# on a récupéré 194908 résultats
# on a récupéré 195392 résultats
# on a récupéré 195878 résultats
# on a récupéré 196368 résultats
# on a récupéré 196857 résultats
# on a récupéré 197337 résultats
# on a récupéré 197820 résultats
# on a récupéré 198302 résultats
# 5000 results collected, making a break
# on a récupéré 198794 résultats
# on a récupéré 199273 résultats
# on a récupéré 199761 résultats
# on a récupéré 200239 résultats
# on a récupéré 200731 résultats
# on a récupéré 201202 résultats
# on a récupéré 201695 résultats
# on a récupéré 202181 résultats
# on a récupéré 202669 résultats
# on a récupéré 203148 résultats
# 5000 results collected, making a break
# on a récupéré 203632 résultats
# on a récupéré 204110 résultats
# on a récupéré 204595 résultats
# on a récupéré 205079 résultats
# on a récupéré 205571 résultats
# on a récupéré 206047 résultats
# on a récupéré 206534 résultats
# on a récupéré 207022 résultats
# on a récupéré 207502 résultats
# on a récupéré 207989 résultats
# 5000 results collected, making a break
# on a récupéré 208478 résultats
# on a récupéré 208964 résultats
# on a récupéré 209458 résultats
# on a récupéré 209939 résultats
# on a récupéré 210414 résultats
# on a récupéré 210899 résultats
# on a récupéré 211366 résultats
# on a récupéré 211851 résultats
# on a récupéré 212328 résultats
# on a récupéré 212807 résultats
# 5000 results collected, making a break
# on a récupéré 213291 résultats
# on a récupéré 213774 résultats
# on a récupéré 214247 résultats
# on a récupéré 214736 résultats
# on a récupéré 215223 résultats
# on a récupéré 215709 résultats
# on a récupéré 216180 résultats
# on a récupéré 216647 résultats
# on a récupéré 217127 résultats
# on a récupéré 217610 résultats
# 5000 results collected, making a break
# on a récupéré 218088 résultats
# on a récupéré 218574 résultats
# on a récupéré 219059 résultats
# on a récupéré 219544 résultats
# on a récupéré 220034 résultats
# on a récupéré 220519 résultats
# on a récupéré 221001 résultats
# on a récupéré 221478 résultats
# on a récupéré 221951 résultats
# on a récupéré 222438 résultats
# 5000 results collected, making a break
# on a récupéré 222927 résultats
# on a récupéré 223414 résultats
# on a récupéré 223901 résultats
# on a récupéré 224384 résultats
# on a récupéré 224864 résultats
# on a récupéré 225345 résultats
# on a récupéré 225833 résultats
# on a récupéré 226316 résultats
# on a récupéré 226806 résultats
# on a récupéré 227292 résultats
# 5000 results collected, making a break
# on a récupéré 227779 résultats
# on a récupéré 228261 résultats
# on a récupéré 228747 résultats
# on a récupéré 229226 résultats
# on a récupéré 229711 résultats
# on a récupéré 230199 résultats
# on a récupéré 230688 résultats
# on a récupéré 231166 résultats
# on a récupéré 231648 résultats
# on a récupéré 232141 résultats
# 5000 results collected, making a break
# on a récupéré 232619 résultats
# on a récupéré 233110 résultats
# on a récupéré 233592 résultats
# on a récupéré 234066 résultats
# on a récupéré 234546 résultats
# on a récupéré 235019 résultats
# on a récupéré 235512 résultats
# on a récupéré 236000 résultats
# on a récupéré 236479 résultats
# on a récupéré 236959 résultats
# 5000 results collected, making a break
# on a récupéré 237439 résultats
# on a récupéré 237928 résultats
# on a récupéré 238402 résultats
# on a récupéré 238891 résultats
# on a récupéré 239374 résultats
# on a récupéré 239856 résultats
# on a récupéré 240334 résultats
# on a récupéré 240824 résultats
# on a récupéré 241281 résultats
# on a récupéré 241767 résultats
# 5000 results collected, making a break
# on a récupéré 242246 résultats
# on a récupéré 242733 résultats
# on a récupéré 243217 résultats
# on a récupéré 243697 résultats
# on a récupéré 244168 résultats
# on a récupéré 244653 résultats
# on a récupéré 245121 résultats
# on a récupéré 245599 résultats
# on a récupéré 246072 résultats
# on a récupéré 246563 résultats
# 5000 results collected, making a break
# on a récupéré 247045 résultats
# on a récupéré 247528 résultats
# on a récupéré 248012 résultats
# on a récupéré 248501 résultats
# on a récupéré 248965 résultats
# on a récupéré 249451 résultats
# on a récupéré 249934 résultats
# on a récupéré 250416 résultats
# on a récupéré 250876 résultats
# on a récupéré 251366 résultats
# 5000 results collected, making a break
# on a récupéré 251852 résultats
# on a récupéré 252333 résultats
# on a récupéré 252825 résultats
# on a récupéré 253311 résultats
# on a récupéré 253799 résultats
# on a récupéré 254283 résultats
# on a récupéré 254771 résultats
# on a récupéré 255248 résultats
# on a récupéré 255734 résultats
# on a récupéré 256215 résultats
# 5000 results collected, making a break
# on a récupéré 256683 résultats
# on a récupéré 257157 résultats
# on a récupéré 257644 résultats
# on a récupéré 258115 résultats
# on a récupéré 258588 résultats
# on a récupéré 259076 résultats
# on a récupéré 259560 résultats
# on a récupéré 260039 résultats
# on a récupéré 260523 résultats
# on a récupéré 260983 résultats
# 5000 results collected, making a break
# on a récupéré 261462 résultats
# on a récupéré 261933 résultats
# on a récupéré 262394 résultats
# on a récupéré 262872 résultats
# on a récupéré 263336 résultats
# on a récupéré 263814 résultats
# on a récupéré 264296 résultats
# on a récupéré 264767 résultats
# on a récupéré 265246 résultats
# on a récupéré 265723 résultats
# 5000 results collected, making a break
# on a récupéré 266180 résultats
# on a récupéré 266644 résultats
# on a récupéré 267120 résultats
# on a récupéré 267604 résultats
# on a récupéré 268094 résultats
# on a récupéré 268569 résultats
# on a récupéré 269046 résultats
# on a récupéré 269533 résultats
# on a récupéré 270012 résultats
# on a récupéré 270498 résultats
# 5000 results collected, making a break
# on a récupéré 270981 résultats
# on a récupéré 271453 résultats
# on a récupéré 271929 résultats
# on a récupéré 272422 résultats
# on a récupéré 272910 résultats
# on a récupéré 273390 résultats
# on a récupéré 273868 résultats
# on a récupéré 274351 résultats
# on a récupéré 274814 résultats
# on a récupéré 275258 résultats
# 5000 results collected, making a break
# on a récupéré 275726 résultats
# on a récupéré 276218 résultats
# on a récupéré 276704 résultats
# on a récupéré 277190 résultats
# on a récupéré 277644 résultats
# on a récupéré 278118 résultats
# on a récupéré 278597 résultats
# on a récupéré 279063 résultats
# on a récupéré 279551 résultats
# on a récupéré 280023 résultats
# 5000 results collected, making a break
# on a récupéré 280472 résultats
# on a récupéré 280936 résultats
# on a récupéré 281425 résultats
# on a récupéré 281912 résultats
# on a récupéré 282386 résultats
# on a récupéré 282879 résultats
# on a récupéré 283367 résultats
# on a récupéré 283857 résultats
# on a récupéré 284343 résultats
# on a récupéré 284832 résultats
# 5000 results collected, making a break
# on a récupéré 285316 résultats
# on a récupéré 285802 résultats
# on a récupéré 286274 résultats
# on a récupéré 286761 résultats
# on a récupéré 287247 résultats
# on a récupéré 287713 résultats
# on a récupéré 288200 résultats
# on a récupéré 288691 résultats
# on a récupéré 289170 résultats
# on a récupéré 289662 résultats
# 5000 results collected, making a break
# on a récupéré 290109 résultats
# on a récupéré 290599 résultats
# on a récupéré 291091 résultats
# on a récupéré 291572 résultats
# on a récupéré 292063 résultats
# on a récupéré 292553 résultats
# on a récupéré 293047 résultats
# on a récupéré 293539 résultats
# on a récupéré 294034 résultats
# on a récupéré 294525 résultats
# 5000 results collected, making a break
# on a récupéré 295014 résultats
# on a récupéré 295512 résultats
# on a récupéré 296004 résultats
# on a récupéré 296497 résultats
# on a récupéré 296993 résultats
# on a récupéré 297473 résultats
# on a récupéré 297952 résultats
# on a récupéré 298444 résultats
# on a récupéré 298922 résultats
# on a récupéré 299410 résultats
# 5000 results collected, making a break
# on a récupéré 299902 résultats
# on a récupéré 300392 résultats
# on a récupéré 300885 résultats
# on a récupéré 301355 résultats
# on a récupéré 301848 résultats
# on a récupéré 302337 résultats
# on a récupéré 302828 résultats
# on a récupéré 303318 résultats
# on a récupéré 303807 résultats
# on a récupéré 304290 résultats
# 5000 results collected, making a break
# on a récupéré 304769 résultats
# on a récupéré 305263 résultats
# on a récupéré 305742 résultats
# on a récupéré 306236 résultats
# on a récupéré 306725 résultats
# on a récupéré 307215 résultats
# on a récupéré 307704 résultats
# on a récupéré 308195 résultats
# on a récupéré 308685 résultats
# on a récupéré 309178 résultats
# 5000 results collected, making a break
# on a récupéré 309670 résultats
# on a récupéré 310147 résultats
# on a récupéré 310636 résultats
# on a récupéré 311133 résultats
# on a récupéré 311622 résultats
# on a récupéré 312102 résultats
# on a récupéré 312584 résultats
# on a récupéré 313072 résultats
# on a récupéré 313561 résultats
# on a récupéré 314044 résultats
# 5000 results collected, making a break
# on a récupéré 314527 résultats
# on a récupéré 314999 résultats
# on a récupéré 315484 résultats
# on a récupéré 315973 résultats
# on a récupéré 316466 résultats
# on a récupéré 316955 résultats
# on a récupéré 317446 résultats
# on a récupéré 317936 résultats
# on a récupéré 318422 résultats
# on a récupéré 318907 résultats
# 5000 results collected, making a break
# on a récupéré 319388 résultats
# on a récupéré 319882 résultats
# on a récupéré 320372 résultats
# on a récupéré 320864 résultats
# on a récupéré 321359 résultats
# on a récupéré 321849 résultats
# on a récupéré 322327 résultats
# on a récupéré 322814 résultats
# on a récupéré 323302 résultats
# on a récupéré 323797 résultats
# 5000 results collected, making a break
# on a récupéré 324289 résultats
# on a récupéré 324773 résultats
# on a récupéré 325262 résultats
# on a récupéré 325749 résultats
# on a récupéré 326241 résultats
# on a récupéré 326730 résultats
# on a récupéré 327219 résultats
# on a récupéré 327707 résultats
# on a récupéré 328188 résultats
# on a récupéré 328680 résultats
# 5000 results collected, making a break
# on a récupéré 329171 résultats
# on a récupéré 329654 résultats
# on a récupéré 330138 résultats
# on a récupéré 330622 résultats
# on a récupéré 331112 résultats
# on a récupéré 331592 résultats
# on a récupéré 332071 résultats
# on a récupéré 332559 résultats
# on a récupéré 333036 résultats
# on a récupéré 333518 résultats
# 5000 results collected, making a break
# on a récupéré 334007 résultats
# on a récupéré 334496 résultats
# on a récupéré 334982 résultats
# on a récupéré 335465 résultats
# on a récupéré 335943 résultats
# on a récupéré 336422 résultats
# on a récupéré 336906 résultats
# on a récupéré 337387 résultats
# on a récupéré 337869 résultats
# on a récupéré 338351 résultats
# 5000 results collected, making a break
# on a récupéré 338827 résultats
# on a récupéré 339312 résultats
# on a récupéré 339800 résultats
# on a récupéré 340286 résultats
# on a récupéré 340773 résultats
# on a récupéré 341257 résultats
# on a récupéré 341736 résultats
# on a récupéré 342224 résultats
# on a récupéré 342709 résultats
# on a récupéré 343196 résultats
# 5000 results collected, making a break
# on a récupéré 343687 résultats
# on a récupéré 344173 résultats
# on a récupéré 344660 résultats
# on a récupéré 345146 résultats
# on a récupéré 345629 résultats
# on a récupéré 346117 résultats
# on a récupéré 346601 résultats
# on a récupéré 347083 résultats
# on a récupéré 347567 résultats
# on a récupéré 348056 résultats
# 5000 results collected, making a break
# on a récupéré 348546 résultats
# on a récupéré 349028 résultats
# on a récupéré 349516 résultats
# on a récupéré 349996 résultats
# on a récupéré 350486 résultats
# on a récupéré 350961 résultats
# on a récupéré 351453 résultats
# on a récupéré 351936 résultats
# on a récupéré 352428 résultats
# on a récupéré 352920 résultats
# 5000 results collected, making a break
# on a récupéré 353409 résultats
# on a récupéré 353891 résultats
# on a récupéré 354380 résultats
# on a récupéré 354872 résultats
# on a récupéré 355361 résultats
# on a récupéré 355856 résultats
# on a récupéré 356347 résultats
# on a récupéré 356833 résultats
# on a récupéré 357319 résultats
# on a récupéré 357811 résultats
# 5000 results collected, making a break
# on a récupéré 358304 résultats
# on a récupéré 358791 résultats
# on a récupéré 359269 résultats
# on a récupéré 359755 résultats
# on a récupéré 360233 résultats
# on a récupéré 360711 résultats
# on a récupéré 361198 résultats
# on a récupéré 361686 résultats
# on a récupéré 362171 résultats
# on a récupéré 362654 résultats
# 5000 results collected, making a break
# on a récupéré 363140 résultats
# on a récupéré 363626 résultats
# on a récupéré 363713 résultats
# FINI
# on a récupéré 500 résultats
# 5000 results collected, making a break
# on a récupéré 995 résultats
# on a récupéré 1493 résultats
# on a récupéré 1988 résultats
# on a récupéré 2482 résultats
# on a récupéré 2970 résultats
# on a récupéré 3466 résultats
# on a récupéré 3961 résultats
# on a récupéré 4448 résultats
# on a récupéré 4939 résultats
# on a récupéré 5428 résultats
# 5000 results collected, making a break
# on a récupéré 5912 résultats
# on a récupéré 6400 résultats
# on a récupéré 6892 résultats
# on a récupéré 7379 résultats
# on a récupéré 7870 résultats
# on a récupéré 8350 résultats
# on a récupéré 8834 résultats
# on a récupéré 9318 résultats
# on a récupéré 9810 résultats
# on a récupéré 10303 résultats
# 5000 results collected, making a break
# on a récupéré 10796 résultats
# on a récupéré 11292 résultats
# on a récupéré 11785 résultats
# on a récupéré 12281 résultats
# on a récupéré 12772 résultats
# on a récupéré 13267 résultats
# on a récupéré 13763 résultats
# on a récupéré 14249 résultats
# on a récupéré 14740 résultats
# on a récupéré 15231 résultats
# 5000 results collected, making a break
# on a récupéré 15719 résultats
# on a récupéré 16210 résultats
# on a récupéré 16703 résultats
# on a récupéré 17194 résultats
# on a récupéré 17680 résultats
# on a récupéré 18161 résultats
# on a récupéré 18651 résultats
# on a récupéré 19144 résultats
# on a récupéré 19623 résultats
# on a récupéré 20090 résultats
# 5000 results collected, making a break
# on a récupéré 20560 résultats
# on a récupéré 21038 résultats
# on a récupéré 21526 résultats
# on a récupéré 22004 résultats
# on a récupéré 22485 résultats
# on a récupéré 22965 résultats
# on a récupéré 23455 résultats
# on a récupéré 23942 résultats
# on a récupéré 24436 résultats
# on a récupéré 24926 résultats
# 5000 results collected, making a break
# on a récupéré 25411 résultats
# on a récupéré 25893 résultats
# on a récupéré 26378 résultats
# on a récupéré 26870 résultats
# on a récupéré 27353 résultats
# on a récupéré 27842 résultats
# on a récupéré 28331 résultats
# on a récupéré 28802 résultats
# on a récupéré 29276 résultats
# on a récupéré 29762 résultats
# 5000 results collected, making a break
# on a récupéré 30244 résultats
# on a récupéré 30726 résultats
# on a récupéré 31214 résultats
# on a récupéré 31699 résultats
# on a récupéré 32191 résultats
# on a récupéré 32663 résultats
# on a récupéré 33147 résultats
# on a récupéré 33630 résultats
# on a récupéré 34105 résultats
# on a récupéré 34582 résultats
# 5000 results collected, making a break
# on a récupéré 35069 résultats
# on a récupéré 35548 résultats
# on a récupéré 36025 résultats
# on a récupéré 36503 résultats
# on a récupéré 36976 résultats
# on a récupéré 37464 résultats
# on a récupéré 37943 résultats
# on a récupéré 38395 résultats
# on a récupéré 38861 résultats
# on a récupéré 39331 résultats
# 5000 results collected, making a break
# on a récupéré 39812 résultats
# on a récupéré 40297 résultats
# on a récupéré 40782 résultats
# on a récupéré 41252 résultats
# on a récupéré 41721 résultats
# on a récupéré 42198 résultats
# on a récupéré 42677 résultats
# on a récupéré 43158 résultats
# on a récupéré 43644 résultats
# on a récupéré 44129 résultats
# 5000 results collected, making a break
# on a récupéré 44612 résultats
# on a récupéré 45086 résultats
# on a récupéré 45568 résultats
# on a récupéré 46048 résultats
# on a récupéré 46534 résultats
# on a récupéré 47013 résultats
# on a récupéré 47494 résultats
# on a récupéré 47972 résultats
# on a récupéré 48451 résultats
# on a récupéré 48937 résultats
# 5000 results collected, making a break
# on a récupéré 49412 résultats
# on a récupéré 49892 résultats
# on a récupéré 50373 résultats
# on a récupéré 50864 résultats
# on a récupéré 51346 résultats
# on a récupéré 51835 résultats
# on a récupéré 52318 résultats
# on a récupéré 52800 résultats
# on a récupéré 53282 résultats
# on a récupéré 53770 résultats
# 5000 results collected, making a break
# on a récupéré 54259 résultats
# on a récupéré 54747 résultats
# on a récupéré 55239 résultats
# on a récupéré 55728 résultats
# on a récupéré 56214 résultats
# on a récupéré 56697 résultats
# on a récupéré 57190 résultats
# on a récupéré 57682 résultats
# on a récupéré 58174 résultats
# on a récupéré 58665 résultats
# 5000 results collected, making a break
# on a récupéré 59149 résultats
# on a récupéré 59631 résultats
# on a récupéré 60115 résultats
# on a récupéré 60600 résultats
# on a récupéré 61081 résultats
# on a récupéré 61566 résultats
# on a récupéré 62053 résultats
# on a récupéré 62553 résultats
# on a récupéré 63038 résultats
# on a récupéré 63531 résultats
# 5000 results collected, making a break
# on a récupéré 64014 résultats
# on a récupéré 64498 résultats
# on a récupéré 64986 résultats
# on a récupéré 65466 résultats
# on a récupéré 65955 résultats
# on a récupéré 66441 résultats
# on a récupéré 66916 résultats
# on a récupéré 67402 résultats
# on a récupéré 67889 résultats
# on a récupéré 68376 résultats
# 5000 results collected, making a break
# on a récupéré 68869 résultats
# on a récupéré 69348 résultats
# on a récupéré 69844 résultats
# on a récupéré 70332 résultats
# on a récupéré 70811 résultats
# on a récupéré 71296 résultats
# on a récupéré 71784 résultats
# on a récupéré 72273 résultats
# on a récupéré 72764 résultats
# on a récupéré 73249 résultats
# 5000 results collected, making a break
# on a récupéré 73730 résultats
# on a récupéré 74217 résultats
# on a récupéré 74699 résultats
# on a récupéré 75191 résultats
# on a récupéré 75676 résultats
# on a récupéré 76164 résultats
# on a récupéré 76653 résultats
# on a récupéré 77118 résultats
# on a récupéré 77607 résultats
# on a récupéré 78085 résultats
# 5000 results collected, making a break
# on a récupéré 78564 résultats
# on a récupéré 79042 résultats
# on a récupéré 79514 résultats
# on a récupéré 79538 résultats
# FINI

# %%
get_full_user_tweets(828290598599872515)
# Out:
# on a récupéré 500 résultats
# 5000 results collected, making a break
# on a récupéré 1000 résultats
# on a récupéré 1497 résultats
# on a récupéré 1996 résultats
# on a récupéré 2493 résultats
# on a récupéré 2990 résultats
# on a récupéré 3482 résultats
# on a récupéré 3972 résultats
# on a récupéré 4458 résultats
# on a récupéré 4948 résultats
# on a récupéré 5432 résultats
# 5000 results collected, making a break
# on a récupéré 5915 résultats
# on a récupéré 6410 résultats
# on a récupéré 6903 résultats
# on a récupéré 7393 résultats
# on a récupéré 7880 résultats
# on a récupéré 8370 résultats
# on a récupéré 8854 résultats
# on a récupéré 9350 résultats
# on a récupéré 9833 résultats
# on a récupéré 10322 résultats
# 5000 results collected, making a break
# on a récupéré 10788 résultats
# on a récupéré 11278 résultats
# on a récupéré 11766 résultats
# on a récupéré 12264 résultats
# on a récupéré 12746 résultats
# on a récupéré 13237 résultats
# on a récupéré 13711 résultats
# on a récupéré 14197 résultats
# on a récupéré 14682 résultats
# on a récupéré 15162 résultats
# 5000 results collected, making a break
# on a récupéré 15647 résultats
# on a récupéré 16126 résultats
# on a récupéré 16594 résultats
# on a récupéré 17075 résultats
# on a récupéré 17560 résultats
# on a récupéré 18046 résultats
# on a récupéré 18532 résultats
# on a récupéré 19017 résultats
# on a récupéré 19506 résultats
# on a récupéré 19993 résultats
# 5000 results collected, making a break
# on a récupéré 20473 résultats
# on a récupéré 20959 résultats
# on a récupéré 21440 résultats
# on a récupéré 21918 résultats
# on a récupéré 22393 résultats
# on a récupéré 22878 résultats
# on a récupéré 23366 résultats
# on a récupéré 23854 résultats
# on a récupéré 24341 résultats
# on a récupéré 24823 résultats
# 5000 results collected, making a break
# on a récupéré 25305 résultats
# on a récupéré 25787 résultats
# on a récupéré 26270 résultats
# on a récupéré 26757 résultats
# on a récupéré 27242 résultats
# on a récupéré 27731 résultats
# on a récupéré 28223 résultats
# on a récupéré 28715 résultats
# on a récupéré 29204 résultats
# on a récupéré 29692 résultats
# 5000 results collected, making a break
# on a récupéré 30180 résultats
# on a récupéré 30670 résultats
# on a récupéré 31161 résultats
# on a récupéré 31654 résultats
# on a récupéré 32146 résultats
# on a récupéré 32635 résultats
# on a récupéré 33125 résultats
# on a récupéré 33615 résultats
# on a récupéré 34106 résultats
# on a récupéré 34596 résultats
# 5000 results collected, making a break
# on a récupéré 35090 résultats
# on a récupéré 35580 résultats
# on a récupéré 36068 résultats
# on a récupéré 36558 résultats
# on a récupéré 37049 résultats
# on a récupéré 37541 résultats
# on a récupéré 38034 résultats
# on a récupéré 38520 résultats
# on a récupéré 39011 résultats
# on a récupéré 39497 résultats
# 5000 results collected, making a break
# on a récupéré 39984 résultats
# on a récupéré 40468 résultats
# on a récupéré 40966 résultats
# on a récupéré 41459 résultats
# on a récupéré 41952 résultats
# on a récupéré 42448 résultats
# on a récupéré 42935 résultats
# on a récupéré 43431 résultats
# on a récupéré 43920 résultats
# on a récupéré 44415 résultats
# 5000 results collected, making a break
# on a récupéré 44901 résultats
# on a récupéré 45376 résultats
# on a récupéré 45854 résultats
# on a récupéré 46344 résultats
# on a récupéré 46822 résultats
# on a récupéré 47313 résultats
# on a récupéré 47796 résultats
# on a récupéré 48290 résultats
# on a récupéré 48774 résultats
# on a récupéré 49262 résultats
# 5000 results collected, making a break
# on a récupéré 49741 résultats
# on a récupéré 50228 résultats
# on a récupéré 50706 résultats
# on a récupéré 50908 résultats
# FINI

# %%
id = 921022848596144128
res = s.get(API_ROUTE + 'users/by?usernames=elleaime53')
res.json()
# Out:
# {'data': [{'id': '828290598599872515',
#    'name': 'LOULOU53',
#    'username': 'elleaime53'}]}

# %%
files = os.listdir(ROOT_FOLDER)
d = {}
for f in files:
    id_ = f.split('-')[0]
    if id_ not in d:
        d[id_] = []
    d[id_].append(f)
d.keys()
# Out:
# dict_keys(['1146074724', '19822406', '2261320772', '2756277147', '3336943089', '493640854', '627503827', '72489273', '828290598599872515'])

# %%
def tweets_to_csv(folder):
    head = "id;text;created_at;possibly_sensitive;reply_settings;source;retweet_count;reply_count;like_count;quote_count;referenced_tweets;images_url;in_reply_to_user_id;in_reply_to_user_name;in_reply_to_user_username"
    for key in d:
        with open(f'{key}.csv', 'w') as f:
            f.write(head)
        for i in range(len(d[key])):
            tweets = {}
            path = os.path.join(folder, f'{key}-{i}.json')
            print(path)
            with open(path, 'r', encoding='utf-8') as f:
                tweets = json.load(f)
            media = tweets['includes'].get('media', [])
            users = tweets['includes'].get('users', [])
            for tweet in tweets['data']:
                metrics = tweet['public_metrics']
                referenced_tweets = ' '.join([t['id'] for t in tweet.get('referenced_tweets', [])])
                media_keys = tweet.get('attachments', {}).get('media_keys', [])
                images_url = []
                if media_keys:
                    for medium in media:
                        if medium['media_key'] in media_keys and 'url' in medium:
                            images_url.append(medium['url'])
                in_reply_to_user_id = tweet.get('in_reply_to_user_id', None)
                in_reply_to = {}
                if in_reply_to_user_id:
                    for user in users:
                        if user['id'] == in_reply_to_user_id:
                            in_reply_to = user
                row = "\n"
                row += f"""{tweet['id']};"{tweet['text'].strip()}";{tweet['created_at']};""".replace('\n', ' ')
                row += f"{tweet['possibly_sensitive']};{tweet['reply_settings']};{tweet['source']};"
                row += f"{metrics['retweet_count']};{metrics['reply_count']};{metrics['like_count']};{metrics['quote_count']};"
                row += f"{referenced_tweets or 'NA'};"
                row += f"{' '.join(images_url) if images_url else 'NA'};"
                row += f"{in_reply_to_user_id or 'NA'};{in_reply_to.get('name', 'NA')};{in_reply_to.get('username', 'NA')}"
                with open(f'{key}.csv', 'a', encoding='utf-8') as f:
                    f.write(row)

# %%
tweets_to_csv(ROOT_FOLDER)
# Out:
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-0.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-1.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-2.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-3.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-4.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-5.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-6.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-7.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-8.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-9.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-10.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-11.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-12.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-13.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-14.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-15.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-16.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-17.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-18.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-19.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-20.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-21.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-22.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-23.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-24.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-25.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-26.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-27.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-28.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-29.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-30.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-31.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-32.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-33.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-34.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-35.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-36.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-37.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-38.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-39.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-40.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-41.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-42.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-43.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-44.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-45.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-46.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-47.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-48.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-49.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-50.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-51.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-52.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-53.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-54.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-55.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-56.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-57.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-58.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-59.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-60.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-61.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-62.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-63.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-64.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-65.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-66.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-67.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-68.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-69.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-70.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-71.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-72.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-73.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-74.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-75.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-76.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-77.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-78.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-79.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-80.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-81.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-82.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-83.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-84.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-85.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-86.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-87.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-88.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-89.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-90.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-91.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-92.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-93.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-94.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-95.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-96.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-97.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-98.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-99.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-100.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-101.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-102.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-103.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-104.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-105.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-106.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-107.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-108.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-109.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-110.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-111.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-112.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-113.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-114.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-115.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-116.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-117.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-118.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-119.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-120.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-121.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-122.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-123.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-124.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-125.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-126.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-127.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-128.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-129.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-130.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-131.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-132.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-133.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-134.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-135.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-136.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-137.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-138.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-139.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-140.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-141.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-142.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-143.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-144.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-145.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-146.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-147.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-148.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-149.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-150.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-151.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-152.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-153.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-154.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-155.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-156.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-157.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-158.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-159.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-160.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-161.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-162.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-163.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-164.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-165.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-166.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-167.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-168.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-169.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-170.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-171.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-172.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\1146074724-173.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-0.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-1.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-2.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-3.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-4.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-5.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-6.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-7.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-8.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-9.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-10.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-11.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-12.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-13.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-14.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-15.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-16.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-17.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-18.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-19.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-20.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-21.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-22.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-23.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-24.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-25.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-26.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-27.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-28.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-29.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-30.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-31.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-32.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-33.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-34.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-35.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-36.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-37.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-38.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-39.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-40.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-41.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-42.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-43.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-44.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-45.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-46.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-47.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-48.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-49.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-50.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-51.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-52.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-53.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-54.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-55.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-56.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-57.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-58.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-59.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-60.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-61.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-62.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-63.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-64.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-65.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-66.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-67.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-68.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-69.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-70.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-71.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-72.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-73.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-74.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-75.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-76.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-77.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-78.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-79.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-80.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-81.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-82.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-83.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-84.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-85.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-86.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-87.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-88.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-89.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-90.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-91.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-92.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-93.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-94.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-95.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-96.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-97.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-98.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-99.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-100.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-101.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-102.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-103.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-104.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-105.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-106.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-107.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-108.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-109.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-110.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-111.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-112.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-113.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-114.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-115.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-116.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-117.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-118.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-119.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-120.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-121.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-122.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-123.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-124.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-125.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-126.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-127.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-128.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-129.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-130.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-131.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-132.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-133.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-134.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-135.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-136.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-137.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-138.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-139.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-140.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-141.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-142.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-143.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-144.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-145.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-146.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-147.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-148.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-149.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-150.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-151.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-152.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-153.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-154.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-155.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-156.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-157.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-158.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-159.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-160.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-161.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-162.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-163.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-164.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-165.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-166.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-167.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-168.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-169.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-170.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-171.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-172.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-173.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-174.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-175.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-176.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-177.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-178.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-179.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-180.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-181.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-182.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-183.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-184.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-185.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-186.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-187.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-188.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-189.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-190.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-191.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-192.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-193.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-194.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-195.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-196.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-197.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-198.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-199.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-200.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-201.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-202.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-203.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-204.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-205.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-206.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-207.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-208.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-209.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-210.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-211.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-212.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-213.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-214.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-215.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-216.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-217.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-218.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-219.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-220.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-221.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-222.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-223.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-224.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-225.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-226.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-227.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-228.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-229.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-230.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-231.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-232.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-233.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-234.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-235.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-236.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-237.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-238.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-239.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-240.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-241.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-242.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-243.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-244.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-245.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-246.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-247.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-248.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-249.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-250.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-251.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-252.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-253.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-254.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-255.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-256.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-257.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-258.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-259.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-260.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-261.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-262.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-263.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-264.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-265.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-266.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-267.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-268.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-269.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-270.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-271.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-272.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-273.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-274.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-275.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-276.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-277.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-278.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-279.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-280.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-281.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-282.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-283.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-284.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-285.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-286.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-287.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-288.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-289.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-290.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-291.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-292.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-293.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-294.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-295.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-296.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-297.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-298.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-299.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-300.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-301.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-302.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-303.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-304.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-305.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-306.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-307.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-308.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-309.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-310.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-311.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-312.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-313.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-314.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-315.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-316.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-317.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-318.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-319.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-320.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-321.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-322.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-323.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-324.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-325.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-326.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-327.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-328.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-329.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-330.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-331.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-332.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-333.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-334.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-335.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-336.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-337.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-338.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-339.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-340.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-341.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-342.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-343.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-344.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-345.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-346.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-347.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-348.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-349.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-350.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-351.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-352.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-353.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-354.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-355.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-356.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-357.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-358.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-359.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-360.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-361.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-362.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-363.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-364.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-365.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-366.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-367.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-368.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-369.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-370.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-371.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-372.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-373.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-374.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-375.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-376.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-377.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-378.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-379.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-380.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-381.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-382.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-383.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-384.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-385.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-386.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-387.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-388.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-389.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-390.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-391.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-392.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-393.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-394.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-395.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-396.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-397.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-398.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-399.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-400.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-401.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-402.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-403.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-404.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-405.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-406.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-407.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-408.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-409.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-410.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-411.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-412.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-413.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-414.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-415.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-416.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-417.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-418.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-419.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\19822406-420.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-0.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-1.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-2.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-3.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-4.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-5.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-6.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-7.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-8.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-9.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-10.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-11.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-12.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-13.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-14.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-15.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-16.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-17.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-18.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-19.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-20.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-21.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-22.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-23.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-24.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-25.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-26.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-27.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-28.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-29.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-30.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-31.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-32.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-33.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-34.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-35.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-36.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-37.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-38.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-39.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-40.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-41.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-42.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-43.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-44.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-45.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-46.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-47.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-48.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-49.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-50.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-51.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-52.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-53.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-54.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-55.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-56.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-57.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-58.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\2261320772-59.json
# ...
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-98.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-99.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-100.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-101.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-102.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-103.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-104.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-105.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-106.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-107.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-108.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-109.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-110.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-111.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-112.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-113.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-114.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-115.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-116.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-117.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-118.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-119.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-120.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-121.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-122.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-123.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-124.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-125.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-126.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-127.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-128.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-129.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-130.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-131.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-132.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-133.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-134.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-135.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-136.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-137.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-138.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-139.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-140.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-141.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-142.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-143.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-144.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-145.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-146.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-147.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-148.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-149.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-150.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-151.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-152.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-153.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-154.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-155.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-156.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-157.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-158.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-159.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-160.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-161.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-162.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-163.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-164.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-165.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-166.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-167.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-168.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-169.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-170.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-171.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-172.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-173.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-174.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-175.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-176.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-177.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-178.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-179.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-180.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-181.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-182.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-183.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-184.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-185.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-186.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-187.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-188.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-189.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-190.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-191.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-192.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-193.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-194.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-195.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-196.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-197.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\72489273-198.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-0.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-1.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-2.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-3.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-4.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-5.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-6.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-7.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-8.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-9.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-10.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-11.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-12.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-13.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-14.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-15.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-16.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-17.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-18.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-19.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-20.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-21.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-22.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-23.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-24.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-25.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-26.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-27.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-28.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-29.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-30.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-31.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-32.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-33.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-34.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-35.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-36.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-37.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-38.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-39.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-40.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-41.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-42.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-43.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-44.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-45.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-46.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-47.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-48.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-49.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-50.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-51.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-52.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-53.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-54.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-55.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-56.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-57.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-58.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-59.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-60.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-61.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-62.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-63.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-64.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-65.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-66.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-67.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-68.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-69.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-70.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-71.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-72.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-73.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-74.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-75.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-76.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-77.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-78.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-79.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-80.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-81.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-82.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-83.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-84.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-85.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-86.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-87.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-88.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-89.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-90.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-91.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-92.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-93.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-94.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-95.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-96.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-97.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-98.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-99.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-100.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-101.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-102.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-103.json
# C:\Users\Orion\Documents\Projets\CERES\PMA\UsersTweets\828290598599872515-104.json
